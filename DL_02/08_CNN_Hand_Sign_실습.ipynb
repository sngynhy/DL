# %% [markdown]
# # CNN을 이용한 손글씨 분류

# %% [markdown]
# 손가락으로 숫자를 표현하는 사진들을 학습하여 나타내고 있는 숫자(0-6)를 예측하는 문제를 실습
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터 로드 및 확인

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# ## 모델 구축

# %% [markdown]
# ###  학습 및 평가

# %% [markdown]
# ### 나의 사진 테스트
# - 본인 사진을 찍어 학습
